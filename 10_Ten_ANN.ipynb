# %% [markdown]
# ### ASSIGNMENT No: 10
#
# Title: Write Python program to implement CNN object detection. Discuss numerous performance evaluation metrics for evaluating the object detecting algorithms' performance.
#
# Problem Statement:  Implement any one of the following Expert System

# %%
# !pip install ultralytics opencv-python matplotlib numpy

# (Latest version upgrade)
# !pip install -U ultralytics opencv-python matplotlib numpy

#Optional (only if error comes)
## !pip install torch torchvision

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO
import numpy as np
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 24.6MB/s 0.3s.2s<0.1s
#  Model Loaded

# %%
model = YOLO("yolov8n.pt") 
print(" Model Loaded")

# %%
# Image path (change accordingly or get an image and rename it Image.jpg and keep it in the same directory as this notebook) 
image_path = "./Image.jpg"

# %%
# Read image 
img = cv2.imread(image_path) 

if img is None: 
    print(" Image NOT found. Fix path!") 
else: 
    print(" Image Loaded Successfully")
# Out:
#  Image Loaded Successfully

# %%
# Run detection 
results = model(image_path) 
print(" Detection Done")
# Out:
# image 1/1 c:\D Drive\Karm\Test\Practical-Codes\ANN Practical Codes\Image.jpg: 320x640 1 car, 221.4ms
# Speed: 10.2ms preprocess, 221.4ms inference, 69.4ms postprocess per image at shape (1, 3, 320, 640)
#  Detection Done

# %%
# Extract detected objects 
detected_objects = [] 

for r in results: 
    for box in r.boxes: 
        cls = int(box.cls[0]) 
        label = model.names[cls] 
        detected_objects.append(label) 

print("Detected Objects:", detected_objects)
# Out:
# Detected Objects: ['car']

# %%
annotated_img = results[0].plot()

# %%
plt.imshow(annotated_img)
plt.title("Detected Objects (YOLO)")
plt.axis("off")
plt.show()
